# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavieng
# Processing Record 2 of Set 1 | longyearbyen
# Processing Record 3 of Set 1 | goderich
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | kuala sungai baru
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | maun
# Processing Record 8 of Set 1 | port hardy
# Processing Record 9 of Set 1 | noumea
# Processing Record 10 of Set 1 | yuanping
# Processing Record 11 of Set 1 | salalah
# Processing Record 12 of Set 1 | san patricio
# Processing Record 13 of Set 1 | sterling
# Processing Record 14 of Set 1 | tessalit
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | sovetskiy
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | merauke
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | kaifeng
# Processing Record 21 of Set 1 | cherskiy
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | tarrafal
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | shimoda
# Processing Record 27 of Set 1 | bolobo
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | coquimbo
# Processing Record 30 of Set 1 | fortuna
# Processing Record 31 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | muros
# Processing Record 35 of Set 1 | daru
# Processing Record 36 of Set 1 | marawi
# Processing Record 37 of Set 1 | moranbah
# Processing Record 38 of Set 1 | adrar
# Processing Record 39 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | cabo san lucas
# Processing Record 49 of Set 1 | black river
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | amga
# Processing Record 2 of Set 2 | mount gambier
# Processing Record 3 of Set 2 | atsiki
# City not found. Skipping...
# Processing Record 4 of Set 2 | banda aceh
# Processing Record 5 of Set 2 | paungde
# Processing Record 6 of Set 2 | vila velha
# Processing Record 7 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 2 | alice town
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | galgani
# City not found. Skipping...
# Processing Record 11 of Set 2 | sorong
# Processing Record 12 of Set 2 | vanimo
# Processing Record 13 of Set 2 | corinth
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | richards bay
# Processing Record 17 of Set 2 | faanui
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | ayagoz
# Processing Record 21 of Set 2 | ikom
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | ola
# Processing Record 26 of Set 2 | puerto ayacucho
# Processing Record 27 of Set 2 | sao filipe
# Processing Record 28 of Set 2 | yulara
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | estelle
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 2 | marzuq
# Processing Record 35 of Set 2 | grindavik
# Processing Record 36 of Set 2 | larap
# Processing Record 37 of Set 2 | castro
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | deh rawud
# City not found. Skipping...
# Processing Record 40 of Set 2 | te anau
# Processing Record 41 of Set 2 | mount isa
# Processing Record 42 of Set 2 | arman
# Processing Record 43 of Set 2 | sanguem
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | ayan
# Processing Record 46 of Set 2 | babu
# Processing Record 47 of Set 2 | surt
# Processing Record 48 of Set 2 | bengkulu
# Processing Record 49 of Set 2 | port-cartier
# Processing Record 50 of Set 2 | lagoa
# Processing Record 1 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | neka
# Processing Record 4 of Set 3 | yumen
# Processing Record 5 of Set 3 | talnakh
# Processing Record 6 of Set 3 | souillac
# Processing Record 7 of Set 3 | touros
# Processing Record 8 of Set 3 | bilibino
# Processing Record 9 of Set 3 | belmonte
# Processing Record 10 of Set 3 | denpasar
# Processing Record 11 of Set 3 | charters towers
# Processing Record 12 of Set 3 | kapaa
# Processing Record 13 of Set 3 | lumphat
# Processing Record 14 of Set 3 | bogale
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | matay
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | lata
# Processing Record 20 of Set 3 | karagaylinskiy
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | nanortalik
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | lunenburg
# Processing Record 25 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | meybod
# Processing Record 28 of Set 3 | imbituba
# Processing Record 29 of Set 3 | ponta do sol
# Processing Record 30 of Set 3 | komsomolskiy
# Processing Record 31 of Set 3 | botwood
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | harlingen
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | newtownards
# Processing Record 36 of Set 3 | kalinovskaya
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | vao
# Processing Record 39 of Set 3 | tokur
# Processing Record 40 of Set 3 | mto wa mbu
# Processing Record 41 of Set 3 | novopavlovka
# Processing Record 42 of Set 3 | micheweni
# Processing Record 43 of Set 3 | leningradskiy
# Processing Record 44 of Set 3 | yellowknife
# Processing Record 45 of Set 3 | linqiong
# Processing Record 46 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 48 of Set 3 | acuna
# City not found. Skipping...
# Processing Record 49 of Set 3 | sumkino
# Processing Record 50 of Set 3 | bambous virieux
# Processing Record 1 of Set 4 | sayat
# Processing Record 2 of Set 4 | coahuayana
# Processing Record 3 of Set 4 | eregli
# Processing Record 4 of Set 4 | neon soulion
# Processing Record 5 of Set 4 | tallahassee
# Processing Record 6 of Set 4 | kassala
# Processing Record 7 of Set 4 | san ignacio
# Processing Record 8 of Set 4 | hangu
# Processing Record 9 of Set 4 | hailey
# Processing Record 10 of Set 4 | umm lajj
# Processing Record 11 of Set 4 | krasnoselkup
# Processing Record 12 of Set 4 | saint marys
# Processing Record 13 of Set 4 | mitsamiouli
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | jumla
# Processing Record 16 of Set 4 | vershino-darasunskiy
# Processing Record 17 of Set 4 | bubaque
# Processing Record 18 of Set 4 | dharchula
# Processing Record 19 of Set 4 | port hedland
# Processing Record 20 of Set 4 | kavaratti
# Processing Record 21 of Set 4 | lithakia
# Processing Record 22 of Set 4 | ajdabiya
# Processing Record 23 of Set 4 | intipuca
# Processing Record 24 of Set 4 | deputatskiy
# Processing Record 25 of Set 4 | zhoucheng
# Processing Record 26 of Set 4 | orange cove
# Processing Record 27 of Set 4 | ambilobe
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | broome
# Processing Record 30 of Set 4 | victoria
# Processing Record 31 of Set 4 | roma
# Processing Record 32 of Set 4 | sinjar
# Processing Record 33 of Set 4 | ruwi
# Processing Record 34 of Set 4 | new norfolk
# Processing Record 35 of Set 4 | wonthaggi
# Processing Record 36 of Set 4 | tuktoyaktuk
# Processing Record 37 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 4 | saint-philippe
# Processing Record 39 of Set 4 | verkhnyaya inta
# Processing Record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 4 | itamaraca
# Processing Record 42 of Set 4 | ahipara
# Processing Record 43 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 4 | saint-joseph
# Processing Record 45 of Set 4 | butaritari
# Processing Record 46 of Set 4 | isangel
# Processing Record 47 of Set 4 | kampot
# Processing Record 48 of Set 4 | yeroham
# Processing Record 49 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 4 | honiara
# Processing Record 1 of Set 5 | walvis bay
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | gasa
# Processing Record 4 of Set 5 | santa cruz
# Processing Record 5 of Set 5 | luena
# Processing Record 6 of Set 5 | saint george
# Processing Record 7 of Set 5 | kongolo
# Processing Record 8 of Set 5 | korla
# Processing Record 9 of Set 5 | marshall
# Processing Record 10 of Set 5 | bell ville
# Processing Record 11 of Set 5 | port moresby
# Processing Record 12 of Set 5 | faya
# Processing Record 13 of Set 5 | gat
# Processing Record 14 of Set 5 | upernavik
# Processing Record 15 of Set 5 | miraflores
# Processing Record 16 of Set 5 | ostrovnoy
# Processing Record 17 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 5 | kupang
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | tiarei
# Processing Record 21 of Set 5 | taonan
# Processing Record 22 of Set 5 | meulaboh
# Processing Record 23 of Set 5 | hithadhoo
# Processing Record 24 of Set 5 | saldanha
# Processing Record 25 of Set 5 | ulladulla
# Processing Record 26 of Set 5 | asmara
# Processing Record 27 of Set 5 | waipawa
# Processing Record 28 of Set 5 | kalmunai
# Processing Record 29 of Set 5 | nuuk
# Processing Record 30 of Set 5 | boundiali
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | chapais
# Processing Record 33 of Set 5 | esperance
# Processing Record 34 of Set 5 | lavrentiya
# Processing Record 35 of Set 5 | hualmay
# Processing Record 36 of Set 5 | tasiilaq
# Processing Record 37 of Set 5 | havelock
# Processing Record 38 of Set 5 | zhanakorgan
# Processing Record 39 of Set 5 | axim
# Processing Record 40 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 5 | kleck
# City not found. Skipping...
# Processing Record 42 of Set 5 | charagua
# Processing Record 43 of Set 5 | puerto carreno
# Processing Record 44 of Set 5 | coihaique
# Processing Record 45 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 5 | coolum beach
# Processing Record 47 of Set 5 | vrangel
# Processing Record 48 of Set 5 | half moon bay
# Processing Record 49 of Set 5 | hoi an
# Processing Record 50 of Set 5 | tazovskiy
# Processing Record 1 of Set 6 | price
# Processing Record 2 of Set 6 | blackwater
# Processing Record 3 of Set 6 | emerald
# Processing Record 4 of Set 6 | qaanaaq
# Processing Record 5 of Set 6 | khatanga
# Processing Record 6 of Set 6 | kosa
# Processing Record 7 of Set 6 | soyo
# Processing Record 8 of Set 6 | dikson
# Processing Record 9 of Set 6 | kokopo
# Processing Record 10 of Set 6 | srednekolymsk
# Processing Record 11 of Set 6 | flinders
# Processing Record 12 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 6 | neftcala
# Processing Record 14 of Set 6 | channel-port aux basques
# Processing Record 15 of Set 6 | alofi
# Processing Record 16 of Set 6 | bardiyah
# Processing Record 17 of Set 6 | kodiak
# Processing Record 18 of Set 6 | ancud
# Processing Record 19 of Set 6 | aksu
# Processing Record 20 of Set 6 | norman wells
# Processing Record 21 of Set 6 | ibi
# Processing Record 22 of Set 6 | vanavara
# Processing Record 23 of Set 6 | tuatapere
# Processing Record 24 of Set 6 | bathsheba
# Processing Record 25 of Set 6 | mumford
# Processing Record 26 of Set 6 | dudinka
# Processing Record 27 of Set 6 | burnie
# Processing Record 28 of Set 6 | corrientes
# Processing Record 29 of Set 6 | cirpan
# City not found. Skipping...
# Processing Record 30 of Set 6 | naples
# Processing Record 31 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 6 | assai
# Processing Record 33 of Set 6 | lorengau
# Processing Record 34 of Set 6 | smolenka
# Processing Record 35 of Set 6 | kaeo
# Processing Record 36 of Set 6 | leh
# Processing Record 37 of Set 6 | ust-nera
# Processing Record 38 of Set 6 | baia de fier
# Processing Record 39 of Set 6 | tecoanapa
# Processing Record 40 of Set 6 | maniitsoq
# Processing Record 41 of Set 6 | quesnel
# Processing Record 42 of Set 6 | vila franca do campo
# Processing Record 43 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 6 | sinnamary
# Processing Record 45 of Set 6 | opuwo
# Processing Record 46 of Set 6 | yar-sale
# Processing Record 47 of Set 6 | adre
# Processing Record 48 of Set 6 | matamoros
# Processing Record 49 of Set 6 | zonguldak
# Processing Record 50 of Set 6 | portland
# Processing Record 1 of Set 7 | yenotayevka
# Processing Record 2 of Set 7 | saint-pierre
# Processing Record 3 of Set 7 | cowra
# Processing Record 4 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 7 | ijui
# Processing Record 6 of Set 7 | papayal
# Processing Record 7 of Set 7 | kathu
# Processing Record 8 of Set 7 | guerrero
# Processing Record 9 of Set 7 | cockburn town
# Processing Record 10 of Set 7 | mahon
# Processing Record 11 of Set 7 | xiongzhou
# Processing Record 12 of Set 7 | boden
# Processing Record 13 of Set 7 | college
# Processing Record 14 of Set 7 | taseyevo
# Processing Record 15 of Set 7 | novyy urengoy
# Processing Record 16 of Set 7 | lamu
# Processing Record 17 of Set 7 | berwick
# Processing Record 18 of Set 7 | north myrtle beach
# Processing Record 19 of Set 7 | ranfurly
# Processing Record 20 of Set 7 | north vanlaiphai
# Processing Record 21 of Set 7 | shubarkuduk
# Processing Record 22 of Set 7 | troitskoye
# Processing Record 23 of Set 7 | urumqi
# Processing Record 24 of Set 7 | atambua
# Processing Record 25 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 7 | bayonet point
# Processing Record 27 of Set 7 | aginskoye
# Processing Record 28 of Set 7 | haines junction
# Processing Record 29 of Set 7 | hendaye
# Processing Record 30 of Set 7 | katsuura
# Processing Record 31 of Set 7 | avera
# Processing Record 32 of Set 7 | komatipoort
# Processing Record 33 of Set 7 | diffa
# Processing Record 34 of Set 7 | pimenteiras
# Processing Record 35 of Set 7 | chibuto
# Processing Record 36 of Set 7 | san carlos
# Processing Record 37 of Set 7 | dalianwan
# Processing Record 38 of Set 7 | lasa
# Processing Record 39 of Set 7 | margate
# Processing Record 40 of Set 7 | narsaq
# Processing Record 41 of Set 7 | beringovskiy
# Processing Record 42 of Set 7 | sao benedito do rio preto
# Processing Record 43 of Set 7 | sur
# Processing Record 44 of Set 7 | vostok
# Processing Record 45 of Set 7 | moron
# Processing Record 46 of Set 7 | biloxi
# Processing Record 47 of Set 7 | udgir
# Processing Record 48 of Set 7 | secunda
# Processing Record 49 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 7 | lima
# Processing Record 1 of Set 8 | sobolevo
# Processing Record 2 of Set 8 | dawlatabad
# Processing Record 3 of Set 8 | rocha
# Processing Record 4 of Set 8 | lincoln
# Processing Record 5 of Set 8 | nuevo progreso
# Processing Record 6 of Set 8 | zharkent
# Processing Record 7 of Set 8 | dunedin
# Processing Record 8 of Set 8 | port hawkesbury
# Processing Record 9 of Set 8 | yashkino
# Processing Record 10 of Set 8 | zeerust
# Processing Record 11 of Set 8 | olafsvik
# Processing Record 12 of Set 8 | morondava
# Processing Record 13 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 8 | brae
# Processing Record 15 of Set 8 | teruel
# Processing Record 16 of Set 8 | bandarbeyla
# Processing Record 17 of Set 8 | itaituba
# Processing Record 18 of Set 8 | adria
# Processing Record 19 of Set 8 | saint-augustin
# Processing Record 20 of Set 8 | skala fourkas
# Processing Record 21 of Set 8 | anadyr
# Processing Record 22 of Set 8 | chernyshevskiy
# Processing Record 23 of Set 8 | pahrump
# Processing Record 24 of Set 8 | springbok
# Processing Record 25 of Set 8 | cayenne
# Processing Record 26 of Set 8 | graaff-reinet
# Processing Record 27 of Set 8 | tymovskoye
# Processing Record 28 of Set 8 | marondera
# Processing Record 29 of Set 8 | jos
# Processing Record 30 of Set 8 | makakilo city
# Processing Record 31 of Set 8 | mattoon
# Processing Record 32 of Set 8 | katherine
# Processing Record 33 of Set 8 | iqaluit
# Processing Record 34 of Set 8 | turukhansk
# Processing Record 35 of Set 8 | clyde river
# Processing Record 36 of Set 8 | nome
# Processing Record 37 of Set 8 | itarema
# Processing Record 38 of Set 8 | carutapera
# Processing Record 39 of Set 8 | upington
# Processing Record 40 of Set 8 | karpathos
# Processing Record 41 of Set 8 | inuvik
# Processing Record 42 of Set 8 | port lincoln
# Processing Record 43 of Set 8 | abaza
# Processing Record 44 of Set 8 | hit
# Processing Record 45 of Set 8 | anloga
# Processing Record 46 of Set 8 | atar
# Processing Record 47 of Set 8 | shenjiamen
# Processing Record 48 of Set 8 | sao raimundo das mangabeiras
# Processing Record 49 of Set 8 | kysyl-syr
# Processing Record 50 of Set 8 | xuanwu
# Processing Record 1 of Set 9 | celica
# Processing Record 2 of Set 9 | san quintin
# Processing Record 3 of Set 9 | puertollano
# Processing Record 4 of Set 9 | vardo
# Processing Record 5 of Set 9 | miramar
# Processing Record 6 of Set 9 | vorobyevka
# Processing Record 7 of Set 9 | safaga
# Processing Record 8 of Set 9 | luang prabang
# Processing Record 9 of Set 9 | roald
# Processing Record 10 of Set 9 | seddon
# Processing Record 11 of Set 9 | tura
# Processing Record 12 of Set 9 | matara
# Processing Record 13 of Set 9 | chiang rai
# Processing Record 14 of Set 9 | lokosovo
# Processing Record 15 of Set 9 | ixtapa
# Processing Record 16 of Set 9 | kismayo
# Processing Record 17 of Set 9 | curuca
# Processing Record 18 of Set 9 | amapa
# Processing Record 19 of Set 9 | yantai
# Processing Record 20 of Set 9 | namibe
# Processing Record 21 of Set 9 | atasu
# Processing Record 22 of Set 9 | denia
# Processing Record 23 of Set 9 | oktyabrskoye
# Processing Record 24 of Set 9 | draguignan
# Processing Record 25 of Set 9 | bakchar
# Processing Record 26 of Set 9 | pisco
# Processing Record 27 of Set 9 | katobu
# Processing Record 28 of Set 9 | goregaon
# Processing Record 29 of Set 9 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 30 of Set 9 | popondetta
# Processing Record 31 of Set 9 | stornoway
# Processing Record 32 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 9 | mackenzie
# Processing Record 34 of Set 9 | erenhot
# Processing Record 35 of Set 9 | sonoita
# Processing Record 36 of Set 9 | wuning
# Processing Record 37 of Set 9 | preston
# Processing Record 38 of Set 9 | balakirevo
# Processing Record 39 of Set 9 | kerema
# Processing Record 40 of Set 9 | santa rosa
# Processing Record 41 of Set 9 | pokosnoye
# Processing Record 42 of Set 9 | belle fourche
# Processing Record 43 of Set 9 | the valley
# Processing Record 44 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 45 of Set 9 | la ronge
# Processing Record 46 of Set 9 | timra
# Processing Record 47 of Set 9 | sheridan
# Processing Record 48 of Set 9 | masty
# Processing Record 49 of Set 9 | eagle pass
# Processing Record 50 of Set 9 | zlotow
# Processing Record 1 of Set 10 | chumikan
# Processing Record 2 of Set 10 | lyngdal
# Processing Record 3 of Set 10 | fuerte olimpo
# Processing Record 4 of Set 10 | dalnerechensk
# Processing Record 5 of Set 10 | champerico
# Processing Record 6 of Set 10 | sao joao da barra
# Processing Record 7 of Set 10 | calama
# Processing Record 8 of Set 10 | grand gaube
# Processing Record 9 of Set 10 | akdepe
# Processing Record 10 of Set 10 | ekhabi
# Processing Record 11 of Set 10 | ellensburg
# Processing Record 12 of Set 10 | bosaso
# Processing Record 13 of Set 10 | zhigansk
# Processing Record 14 of Set 10 | houma
# Processing Record 15 of Set 10 | kuzino
# Processing Record 16 of Set 10 | sabya
# Processing Record 17 of Set 10 | egvekinot
# Processing Record 18 of Set 10 | bar-le-duc
# Processing Record 19 of Set 10 | nova floresta
# Processing Record 20 of Set 10 | great yarmouth
# Processing Record 21 of Set 10 | robe
# Processing Record 22 of Set 10 | tacuarembo
# Processing Record 23 of Set 10 | nepalganj
# City not found. Skipping...
# Processing Record 24 of Set 10 | husavik
# Processing Record 25 of Set 10 | geraldton
# Processing Record 26 of Set 10 | darnah
# Processing Record 27 of Set 10 | kropotkin
# Processing Record 28 of Set 10 | thiadiaye
# Processing Record 29 of Set 10 | kamina
# Processing Record 30 of Set 10 | hami
# Processing Record 31 of Set 10 | kurilsk
# Processing Record 32 of Set 10 | lebedyan
# Processing Record 33 of Set 10 | asfi
# Processing Record 34 of Set 10 | koumac
# Processing Record 35 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 10 | bukachacha
# Processing Record 37 of Set 10 | potosi
# Processing Record 38 of Set 10 | plastun
# Processing Record 39 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 40 of Set 10 | hyeres
# Processing Record 41 of Set 10 | wajima
# Processing Record 42 of Set 10 | codrington
# Processing Record 43 of Set 10 | tres arroyos
# Processing Record 44 of Set 10 | chocen
# Processing Record 45 of Set 10 | abu dhabi
# Processing Record 46 of Set 10 | kununurra
# Processing Record 47 of Set 10 | athabasca
# Processing Record 48 of Set 10 | tilichiki
# Processing Record 49 of Set 10 | ialibu
# Processing Record 50 of Set 10 | pianoro
# Processing Record 1 of Set 11 | sakakah
# Processing Record 2 of Set 11 | provideniya
# Processing Record 3 of Set 11 | usinsk
# Processing Record 4 of Set 11 | viedma
# Processing Record 5 of Set 11 | ust-maya
# Processing Record 6 of Set 11 | kitimat
# Processing Record 7 of Set 11 | buala
# Processing Record 8 of Set 11 | puerto escondido
# Processing Record 9 of Set 11 | borogontsy
# Processing Record 10 of Set 11 | ambanja
# Processing Record 11 of Set 11 | aklavik
# Processing Record 12 of Set 11 | jiangyou
# Processing Record 13 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 14 of Set 11 | kamien pomorski
# Processing Record 15 of Set 11 | mutare
# Processing Record 16 of Set 11 | padang
# Processing Record 17 of Set 11 | kruisfontein
# Processing Record 18 of Set 11 | huanren
# Processing Record 19 of Set 11 | kosonsoy
# Processing Record 20 of Set 11 | kirakira
# Processing Record 21 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 11 | guerrero negro
# Processing Record 23 of Set 11 | adelaide
# Processing Record 24 of Set 11 | millinocket
# Processing Record 25 of Set 11 | volary
# Processing Record 26 of Set 11 | brancovenesti
# City not found. Skipping...
# Processing Record 27 of Set 11 | naze
# Processing Record 28 of Set 11 | payakumbuh
# Processing Record 29 of Set 11 | bara
# Processing Record 30 of Set 11 | homer
# Processing Record 31 of Set 11 | jishou
# Processing Record 32 of Set 11 | kankaanpaa
# Processing Record 33 of Set 11 | alta floresta
# Processing Record 34 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 11 | san lazaro
# Processing Record 36 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 11 | sekoma
# Processing Record 38 of Set 11 | honningsvag
# Processing Record 39 of Set 11 | stephenville
# Processing Record 40 of Set 11 | jaunjelgava
# Processing Record 41 of Set 11 | oranjemund
# Processing Record 42 of Set 11 | sechura
# Processing Record 43 of Set 11 | sitka
# Processing Record 44 of Set 11 | gizo
# Processing Record 45 of Set 11 | paita
# Processing Record 46 of Set 11 | choix
# Processing Record 47 of Set 11 | zwedru
# Processing Record 48 of Set 11 | luganville
# Processing Record 49 of Set 11 | kerrville
# Processing Record 50 of Set 11 | vitimskiy
# City not found. Skipping...
# Processing Record 1 of Set 12 | los llanos de aridane
# Processing Record 2 of Set 12 | glendive
# Processing Record 3 of Set 12 | karratha
# Processing Record 4 of Set 12 | quatre cocos
# Processing Record 5 of Set 12 | hofn
# Processing Record 6 of Set 12 | laguna
# Processing Record 7 of Set 12 | malinovoye ozero
# Processing Record 8 of Set 12 | kunming
# Processing Record 9 of Set 12 | sampit
# Processing Record 10 of Set 12 | ketchikan
# Processing Record 11 of Set 12 | hamilton
# Processing Record 12 of Set 12 | palmer
# Processing Record 13 of Set 12 | kabanjahe
# Processing Record 14 of Set 12 | ahuimanu
# Processing Record 15 of Set 12 | vilyuysk
# Processing Record 16 of Set 12 | olga
# Processing Record 17 of Set 12 | ruteng
# Processing Record 18 of Set 12 | fuling
# Processing Record 19 of Set 12 | pierre
# Processing Record 20 of Set 12 | porto walter
# Processing Record 21 of Set 12 | erzincan
# Processing Record 22 of Set 12 | bambanglipuro
# Processing Record 23 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 12 | alice springs
# Processing Record 25 of Set 12 | killybegs
# Processing Record 26 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 27 of Set 12 | nhulunbuy
# Processing Record 28 of Set 12 | dingle
# Processing Record 29 of Set 12 | salinas
# Processing Record 30 of Set 12 | san jose
# Processing Record 31 of Set 12 | kahului
# Processing Record 32 of Set 12 | gayeri
# Processing Record 33 of Set 12 | fort nelson
# Processing Record 34 of Set 12 | myshkin
# Processing Record 35 of Set 12 | makokou
# Processing Record 36 of Set 12 | savalou
# Processing Record 37 of Set 12 | wanning
# Processing Record 38 of Set 12 | karlstad
# Processing Record 39 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 40 of Set 12 | dawei
# Processing Record 41 of Set 12 | mendoza
# Processing Record 42 of Set 12 | rupert
# Processing Record 43 of Set 12 | yanam
# Processing Record 44 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 12 | punta alta
# Processing Record 46 of Set 12 | pacific grove
# Processing Record 47 of Set 12 | rosarito
# Processing Record 48 of Set 12 | pedernales
# Processing Record 49 of Set 12 | zelenets
# Processing Record 50 of Set 12 | jimenez
# Processing Record 1 of Set 13 | pochutla
# Processing Record 2 of Set 13 | chanika
# Processing Record 3 of Set 13 | praia
# Processing Record 4 of Set 13 | shelburne
# Processing Record 5 of Set 13 | iskateley
# Processing Record 6 of Set 13 | mao
# Processing Record 7 of Set 13 | fairbanks
# Processing Record 8 of Set 13 | mayor pablo lagerenza
# Processing Record 9 of Set 13 | samarai
# Processing Record 10 of Set 13 | rancho palos verdes
# Processing Record 11 of Set 13 | assare
# Processing Record 12 of Set 13 | socorro
# Processing Record 13 of Set 13 | waingapu
# Processing Record 14 of Set 13 | newberg
# Processing Record 15 of Set 13 | nemuro
# Processing Record 16 of Set 13 | nantucket
# Processing Record 17 of Set 13 | paraiso
# Processing Record 18 of Set 13 | eydhafushi
# Processing Record 19 of Set 13 | shunyi
# Processing Record 20 of Set 13 | tres palos
# Processing Record 21 of Set 13 | presidencia roque saenz pena
# Processing Record 22 of Set 13 | necochea
# Processing Record 23 of Set 13 | churapcha
# Processing Record 24 of Set 13 | svobodnyy
# Processing Record 25 of Set 13 | rawson
# Processing Record 26 of Set 13 | natal
# Processing Record 27 of Set 13 | byron bay
# Processing Record 28 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 29 of Set 13 | buraydah
# Processing Record 30 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 13 | namtsy
# Processing Record 32 of Set 13 | haimen
# Processing Record 33 of Set 13 | almeirim
# Processing Record 34 of Set 13 | shalazhi
# Processing Record 35 of Set 13 | camacupa
# Processing Record 36 of Set 13 | usogorsk
# Processing Record 37 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 38 of Set 13 | boddam
# Processing Record 39 of Set 13 | tabas
# Processing Record 40 of Set 13 | marsh harbour
# Processing Record 41 of Set 13 | lompoc
# Processing Record 42 of Set 13 | svatove
# Processing Record 43 of Set 13 | totma
# Processing Record 44 of Set 13 | bosobolo
# Processing Record 45 of Set 13 | point pedro
# Processing Record 46 of Set 13 | pekan nenas
# Processing Record 47 of Set 13 | mormugao
# Processing Record 48 of Set 13 | lamar
# Processing Record 49 of Set 13 | marsa matruh
# Processing Record 50 of Set 13 | le mans
# Processing Record 1 of Set 14 | panguna
# Processing Record 2 of Set 14 | jasper
# Processing Record 3 of Set 14 | humaita
# Processing Record 4 of Set 14 | andarab
# City not found. Skipping...
# Processing Record 5 of Set 14 | kanniyakumari
# Processing Record 6 of Set 14 | kamaishi
# Processing Record 7 of Set 14 | evanston
# Processing Record 8 of Set 14 | male
# Processing Record 9 of Set 14 | waddan
# Processing Record 10 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 14 | sibolga
# Processing Record 12 of Set 14 | satun
# Processing Record 13 of Set 14 | daugavpils
# Processing Record 14 of Set 14 | mirador
# Processing Record 15 of Set 14 | pitimbu
# Processing Record 16 of Set 14 | harper
# Processing Record 17 of Set 14 | igarka
# Processing Record 18 of Set 14 | wajir
# Processing Record 19 of Set 14 | yerbogachen
# Processing Record 20 of Set 14 | elliot
# Processing Record 21 of Set 14 | paramonga
# Processing Record 22 of Set 14 | evensk
# Processing Record 23 of Set 14 | nishihara
# Processing Record 24 of Set 14 | llangefni
# Processing Record 25 of Set 14 | nouadhibou
# Processing Record 26 of Set 14 | malindi
# Processing Record 27 of Set 14 | vestmannaeyjar
# Processing Record 28 of Set 14 | santa barbara
# Processing Record 29 of Set 14 | finnsnes
# Processing Record 30 of Set 14 | whyalla
# Processing Record 31 of Set 14 | manono
# Processing Record 32 of Set 14 | ipixuna
# Processing Record 33 of Set 14 | kulhudhuffushi
# Processing Record 34 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 14 | duluth
# Processing Record 36 of Set 14 | asau
# Processing Record 37 of Set 14 | roebourne
# Processing Record 38 of Set 14 | leua
# Processing Record 39 of Set 14 | tiznit
# Processing Record 40 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 14 | kirgiz-miyaki
# Processing Record 42 of Set 14 | sao francisco do sul
# Processing Record 43 of Set 14 | monrovia
# Processing Record 44 of Set 14 | yabelo
# Processing Record 45 of Set 14 | lagdo
# Processing Record 46 of Set 14 | dicabisagan
# Processing Record 47 of Set 14 | henties bay
# Processing Record 48 of Set 14 | beloha
# Processing Record 49 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 50 of Set 14 | sola
# Processing Record 1 of Set 15 | puerto leguizamo
# Processing Record 2 of Set 15 | digoin
# Processing Record 3 of Set 15 | port macquarie
# Processing Record 4 of Set 15 | basco
# Processing Record 5 of Set 15 | amahai
# Processing Record 6 of Set 15 | ifakara
# Processing Record 7 of Set 15 | shar
# Processing Record 8 of Set 15 | mporokoso
# Processing Record 9 of Set 15 | turhal
# Processing Record 10 of Set 15 | summerville
# Processing Record 11 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 12 of Set 15 | loviisa
# Processing Record 13 of Set 15 | tigil
# Processing Record 14 of Set 15 | ulaanbaatar
# Processing Record 15 of Set 15 | bremerton
# Processing Record 16 of Set 15 | vero beach
# Processing Record 17 of Set 15 | bukene
# Processing Record 18 of Set 15 | terrasini
# Processing Record 19 of Set 15 | candawaga
# City not found. Skipping...
# Processing Record 20 of Set 15 | puerto baquerizo moreno
# Processing Record 21 of Set 15 | ternate
# Processing Record 22 of Set 15 | sena madureira
# Processing Record 23 of Set 15 | ullapool
# Processing Record 24 of Set 15 | eyl
# Processing Record 25 of Set 15 | santa maria
# Processing Record 26 of Set 15 | gangapur
# Processing Record 27 of Set 15 | san juan
# Processing Record 28 of Set 15 | mariental
# Processing Record 29 of Set 15 | latung
# Processing Record 30 of Set 15 | takoradi
# Processing Record 31 of Set 15 | qaqortoq
# Processing Record 32 of Set 15 | soledade
# Processing Record 33 of Set 15 | tabou
# Processing Record 34 of Set 15 | maldonado
# Processing Record 35 of Set 15 | labuhan
# Processing Record 36 of Set 15 | beihai
# Processing Record 37 of Set 15 | oranjestad
# Processing Record 38 of Set 15 | puri
# Processing Record 39 of Set 15 | karatuzskoye
# Processing Record 40 of Set 15 | swakopmund
# Processing Record 41 of Set 15 | goedereede
# Processing Record 42 of Set 15 | sayanskiy
# City not found. Skipping...
# Processing Record 43 of Set 15 | solnechnyy
# Processing Record 44 of Set 15 | kamenka
# Processing Record 45 of Set 15 | labuan
# Processing Record 46 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 48 of Set 15 | vieste
# Processing Record 49 of Set 15 | flic en flac
# Processing Record 50 of Set 15 | iberia
# Processing Record 1 of Set 16 | fare
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Kavieng      PG  -2.5744  150.7967     83.07        73
# 1       Longyearbyen      SJ  78.2186   15.6401     22.84        74
# 2           Goderich      CA  43.7501  -81.7165     30.90        68
# 3      Mar Del Plata      AR -38.0023  -57.5575     59.88        93
# 4  Kuala Sungai Baru      MY   2.3594  102.0353     78.82        88
# 5            Rikitea      PF -23.1203 -134.9692     77.77        67
# 6               Maun      BW -19.9833   23.4167     85.59        36
# 7         Port Hardy      CA  50.6996 -127.4199     41.61        90
# 8             Noumea      NC -22.2763  166.4572     79.00        99
# 9           Yuanping      CN  38.7153  112.7575     60.15        28
#
#    Cloudiness  Wind Speed Current Description
# 0          96       14.25     overcast clouds
# 1          20        4.61          few clouds
# 2          82       13.33       broken clouds
# 3          75        8.01                 fog
# 4         100       10.47          light rain
# 5          18       11.63          few clouds
# 6          84        7.20       broken clouds
# 7         100       25.21          light rain
# 8         100        1.81     overcast clouds
# 9          32        5.41    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
